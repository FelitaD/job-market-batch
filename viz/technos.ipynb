# %%
import pandas as pd
import ast
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
import string
import re
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to /Users/donor/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
jobs = pd.read_csv('/Users/donor/PycharmProjects/DE_job_market/nlp/english_jobs_ner.csv', index_col=[0])
jobs
# Out:
#                                                     url  \
# 0     https://datai.jobs/job/lyft-data-engineer-kyiv...
# 1     https://datai.jobs/job/chargepoint-data-engine...
# 2     https://datai.jobs/job/spotify-data-engineer-e...
# 3     https://datai.jobs/job/spotify-staff-data-engi...
# 4     https://datai.jobs/job/spotify-data-engineer-s...
# ...                                                 ...
# 1050  https://www.welcometothejungle.com/fr/companie...
# 1057  https://www.welcometothejungle.com/fr/companie...
# 1064  https://www.welcometothejungle.com/fr/companie...
# 1065  https://www.welcometothejungle.com/fr/companie...
# 1069  https://www.welcometothejungle.com/fr/companie...
#
#                                  title               company       location  \
# 0                 Data Engineer – Kyiv                  Lyft  Kyiv, Ukraine
# 1                        Data Engineer           ChargePoint      Amsterdam
# 2           Data Engineer – Experience               Spotify      Stockholm
# 3     Staff Data Engineer – Experience               Spotify      Stockholm
# 4                        Data Engineer               Spotify      Stockholm
# ...                                ...                   ...            ...
# 1050                     Data Engineer  GLOBAL SAVINGS GROUP        München
# 1057                     Data Engineer           Back Market       Bordeaux
# 1064     Data Engineer (Platform team)                Veepee          Paris
# 1065            Data Engineer (Remote)                Stuart              N
# 1069   Data engineer  business centric                Heetch          Paris
#
#            type                                           industry  \
# 0     Full Time                     Vehicles & Autonomous Mobility
# 1     Full Time                     Vehicles & Autonomous Mobility
# 2     Full Time                                      Entertainment
# 3     Full Time                                      Entertainment
# 4     Full Time                                      Entertainment
# ...         ...                                                ...
# 1050        CDI         AdTech / MarTech, E-commerce, IT / Digital
# 1057        CDI  Collaborative Economy, E-commerce, Environment...
# 1064        CDI                                         E-commerce
# 1065        CDI                   Collaborative Economy, Logistics
# 1069        CDI                              Mobile Apps, Mobility
#
#                             remote  created_at  \
# 0                          Inconnu  2021-12-27
# 1                          Inconnu  2021-12-27
# 2                          Inconnu  2021-12-27
# 3                          Inconnu  2021-12-27
# 4                          Inconnu  2021-12-27
# ...                            ...         ...
# 1050                       Inconnu  2022-01-25
# 1057                       Inconnu  2022-01-25
# 1064  Télétravail partiel possible  2022-01-25
# 1065    Télétravail total possible  2022-01-25
# 1069                       Inconnu  2022-01-25
#
#                                                    text  \
# 0     At Lyft, our mission is to improve people’s li...
# 1     Data Engineer\nAbout Us\nWith electric vehicle...
# 2     Delivering the best Spotify experience possibl...
# 3     Delivering the best Spotify experience possibl...
# 4     The Platform team creates the technology that ...
# ...                                                 ...
# 1050  We are the Global Savings Group, the leading E...
# 1057  BackMarket is the number one European (and soo...
# 1064  Avec VEEPEE, le groupe vente-privee ouvre un n...
# 1065  Stuart (DPD Group) is a sustainable 🌱 last-mil...
# 1069  Heetch: the VTC that keeps everyone moving. Ou...
#
#                                          processed_text lang  length_text  \
# 0     lyft mission improve people life world best tr...   en         2672
# 1     data engineer u electric vehicle ev expected n...   en         3229
# 2     delivering best spotify experience possible ma...   en         4143
# 3     delivering best spotify experience possible ma...   en         5233
# 4     platform team creates technology enables spoti...   en         4186
# ...                                                 ...  ...          ...
# 1050  global saving group leading european commerce ...   en         3190
# 1057  backmarket number one european soon global mar...   en         4204
# 1064  veepee groupe venteprivee ouvre nouveau chapit...   en         5032
# 1065  stuart dpd group sustainable lastmile delivery...   en         4097
# 1069  heetch vtc keep everyone moving mission heetch...   en         5692
#
#                                                 technos
# 0     ['S3', 'Flyte', 'ETL', 'Stackdriver', 'Kafka',...
# 1     ['mlflow', 'nodejs', 'airflow', 'Python', 'Air...
# 2     ['Dataflow', 'Kubeflow', 'Pub/Sub', 'BigQuery'...
# 3                           ['Scala', 'Python', 'Java']
# 4     ['Scala', 'Google Cloud Platform', 'Python', '...
# ...                                                 ...
# 1050  ['S3', 'Hadoop', 'Scala', 'Flink', 'Glue', 'EM...
# 1057  ['NoSQL', 'Kafka', 'Go', 'Spark', 'Participati...
# 1064  ['Grafana', 'PostgreSQL', 'Kafka', 'Proficienc...
# 1065  ['S3', 'Redshift', 'Hadoop', 'Flink', 'Kafka',...
# 1069  ['Morocco', 'Algeria', 'airflow', 'SMS', 'Pyth...
#
# [523 rows x 13 columns]

# %%
all_technos = []
for technos in jobs.technos:
    technos = ast.literal_eval(technos)
    all_technos += technos

all_technos
# Out:
# ['S3',
#  'Flyte',
#  'ETL',
#  'Stackdriver',
#  'Kafka',
#  'Hive',
#  'Spark',
#  'SageMaker',
#  'DynamoDB',
#  'Airflow',
#  'ElasticSearch',
#  'SQL',
#  'mlflow',
#  'nodejs',
#  'airflow',
#  'Python',
#  'Airflow',
#  'Kubernetes',
#  'Dataflow',
#  'Kubeflow',
#  'Pub/Sub',
#  'BigQuery',
#  'Apache Beam',
#  'Tensorflow',
#  'Scala',
#  'Python',
#  'Java',
#  'Scala',
#  'Google Cloud Platform',
#  'Python',
#  'Java',
#  'SQL',
#  'Hadoop',
#  'Luigi',
#  'Scala',
#  'Kafka',
#  'Go',
#  'Spark',
#  'Python',
#  'Java',
#  'Scala',
#  'Google Cloud Platform',
#  'Python',
#  'Pub/Sub',
#  'Java',
#  'BigQuery',
#  'GKE',
#  'SQL',
#  'R',
#  'Hadoop',
#  'Spark',
#  'Python',
#  'SQL',
#  'R',
#  'Pandas',
#  'Tableau',
#  'BigQuery',
#  'SQL',
#  'Google Cloud',
#  'airflow',
#  'Talend',
#  'Snowflake',
#  'Python',
#  'AWS',
#  'Looker',
#  'Microsoft Azure',
#  'Airflow',
#  'dbt',
#  'Fivetran',
#  'SQL',
#  'PHP',
#  'MySQL',
#  'Bash',
#  'CloudSQL',
#  'Spanner',
#  'Python',
#  'Golang',
#  'MySQL',
#  'Vitess',
#  'Go',
#  'Ruby',
#  'Java',
#  'MongoDB',
#  'Golang',
#  'Grafana',
#  'Ceph',
#  'C/C++',
#  'Kibana',
#  'Salt',
#  'HDFS',
#  'Quicksilver',
#  'Redis',
#  'Go',
#  'CockroachDB',
#  'Python',
#  'OpenTSDB',
#  'ElasticSearch',
#  'ClickHouse',
#  'PostgreSQL',
#  'Prometheus',
#  'SQL',
#  'Google Cloud',
#  'airflow',
#  'Talend',
#  'Snowflake',
#  'Python',
#  'AWS',
#  'Looker',
#  'Microsoft Azure',
#  'Airflow',
#  'dbt',
#  'Fivetran',
#  'SQL',
#  'Google Cloud',
#  'airflow',
#  'Talend',
#  'Snowflake',
#  'Python',
#  'Airflow',
#  'Looker',
#  'dbt',
#  'Fivetran',
#  'AWS',
#  'Microsoft Azure',
#  'SQL',
#  'R',
#  'Pig',
#  'Hadoop',
#  'Scala',
#  'React',
#  'Spark',
#  'Python',
#  'Javascript',
#  'SQL',
#  'Google Cloud',
#  'airflow',
#  'Talend',
#  'Snowflake',
#  'Python',
#  'AWS',
#  'Looker',
#  'Microsoft Azure',
#  'Airflow',
#  'dbt',
#  'Fivetran',
#  'SQL',
#  'PostgreSQL',
#  'NiFi',
#  'Kafka',
#  'Redshift Spectrum',
#  'Astronomer',
#  'AWS Redshift',
#  'Airflow',
#  'Python',
#  'dbt',
#  'Looker',
#  'AWS',
#  'SQL',
#  'MTTR',
#  'Puppet',
#  'Chef',
#  'AWS',
#  'Microsoft Azure',
#  'SQL',
#  'Scala',
#  'Flink',
#  'Kafka',
#  'Spark',
#  'Java',
#  'Scala',
#  'Flink',
#  'Kafka',
#  'Spark',
#  'Java',
#  'Informatics',
#  'PreSales',
#  'Go',
#  'Informatics',
#  'Dutch',
#  'PreSales',
#  'Go',
#  'PQL',
#  'PowerBI',
#  'DAX',
#  'Tableau',
#  'SAP',
#  'VizQL',
#  'SQL',
#  'PQL',
#  'PowerBI',
#  'DAX',
#  'Tableau',
#  'SAP',
#  'VizQL',
#  'SQL',
#  'Informatics',
#  'PreSales',
#  'Go',
#  'WooCommerce',
#  'Looker',
#  'Longreads',
#  'SQL',
#  'Redshift',
#  'Metabase',
#  'Snowflake',
#  'Python',
#  'Tableau',
#  'Looker',
#  'dbt',
#  'BigQuery',
#  'SQL',
#  'R',
#  'Hadoop',
#  'Python',
#  'Airflow',
#  'Looker',
#  'SQL',
#  'Python',
#  'Economics',
#  'SQL',
#  'Terms',
#  'Scala',
#  'Ruby',
#  'Spark',
#  'Python',
#  'Tensorflow',
#  'ServicePortal',
#  'Dublin',
#  'Python',
#  'SSO',
#  'Java',
#  'JavaScript',
#  'PoCs',
#  'Python',
#  'HTTP',
#  'SQL',
#  'H20',
#  'Scala',
#  'Unix',
#  'Py torch',
#  'Python',
#  'Linux',
#  'Java',
#  'Scikit Learn',
#  'TensorFlow',
#  'R',
#  'Scala',
#  'Pandas',
#  'Python',
#  'Tableau',
#  'BigQuery',
#  'SQL',
#  'R',
#  'Scala',
#  'BigQuery',
#  'Python',
#  'PostgreSQL',
#  'SQL',
#  'MySQL',
#  'Microsoft',
#  'Google',
#  'AWS',
#  'SQL',
#  'ScikitLearn',
#  'H20',
#  'Scala',
#  'Unix',
#  'Python',
#  'Linux',
#  'Java',
#  'TensorFlow',
#  'SQL',
#  'C/C++',
#  'Python',
#  'Java',
#  'Sweden',
#  'Python',
#  'Java',
#  'PowerBI',
#  'Python',
#  'Tableau',
#  'Looker',
#  'Payments',
#  'SQL',
#  'PoCs',
#  'Python',
#  'HTTP',
#  'SQL',
#  'SQL',
#  'PoCs',
#  'Python',
#  'HTTP',
#  'SQL',
#  'PoCs',
#  'Python',
#  'HTTP',
#  'SQL',
#  'R',
#  'Hadoop',
#  'Economics',
#  'Spark',
#  'Python',
#  'SQL',
#  'Python',
#  'R',
#  'Python',
#  'Google BigQuery',
#  'BigQuery',
#  'SQL',
#  'Python',
#  'SQL',
#  'Python',
#  'Tableau',
#  'R',
#  'SQL',
#  'R',
#  'Pandas',
#  'Spark',
#  'Python',
#  'Tableau',
#  'Free',
#  'SQL',
#  'Scala',
#  'Flink',
#  'Kafka',
#  'Spark',
#  'Java',
#  'Hadoop',
#  'Storm',
#  'Google Cloud Platform',
#  'Dataflow',
#  'Spark',
#  'DataFlow',
#  'python',
#  'TensorFlow',
#  'Python',
#  'SQL',
#  'Python',
#  'R',
#  'Economics',
#  'SQL',
#  'Python',
#  'Spark',
#  'Go',
#  'Tensorflow',
#  'Pandas',
#  'Proficiency',
#  'Python',
#  'TensorFlow',
#  'SQL',
#  'Snowflake',
#  'Tableau',
#  'Looker',
#  'SQL',
#  'Docker',
#  'Python',
#  'Net protocols',
#  'Linux',
#  'EST',
#  'Python',
#  'Scikit',
#  'TensorFlow',
#  'German',
#  'Python',
#  'R',
#  'SQL',
#  'Python',
#  'R',
#  'SQL',
#  'Python',
#  'R',
#  'SQL',
#  'RNN',
#  'Google',
#  'GAN',
#  'Tensorflow',
#  'Python',
#  'Tensorflow',
#  'Python',
#  'R',
#  'Hadoop',
#  'Luigi',
#  'Scala',
#  'Spark',
#  'Python',
#  'AWS Redshift',
#  'AWS',
#  'Snowflake',
#  'SQL',
#  'Hadoop',
#  'Luigi',
#  'Scala',
#  'Kafka',
#  'Go',
#  'Spark',
#  'Python',
#  'Kubernetes',
#  'AWS',
#  'Java',
#  'Hadoop',
#  'OOP',
#  'Spark',
#  'Python',
#  'SQL',
#  'Hadoop',
#  'GDPR',
#  'Azure',
#  'Flink',
#  'Scala',
#  'ElasticSearch',
#  'RabbitMQ',
#  'Docker',
#  'C#',
#  'NoSQL',
#  'Python',
#  'Airflow',
#  'dbt',
#  'SQL',
#  'Event',
#  'Kafka',
#  'Snowflake',
#  'AWS',
#  'Java',
#  'S3',
#  'DynamoDB',
#  'Kinesis',
#  'GCP',
#  'RedShift',
#  'Azure',
#  'Google Cloud',
#  'AWS',
#  'Microsoft Azure',
#  'Looker',
#  'GCP',
#  'RedShift',
#  'Azure',
#  'Google Cloud',
#  'AWS',
#  'Microsoft Azure',
#  'Looker',
#  'S3',
#  'Flyte',
#  'ETL',
#  'Stackdriver',
#  'Kafka',
#  'Hive',
#  'Spark',
#  'SageMaker',
#  'DynamoDB',
#  'Airflow',
#  'ElasticSearch',
#  'SQL',
#  'R',
#  'Azure',
#  'Scala',
#  'EKS',
#  'Glue',
#  'SQL',
#  'Kafka',
#  'Spark',
#  'Python',
#  'AWS',
#  'Java',
#  'Kinesis',
#  'Python',
#  'SQL',
#  'Java',
#  'Azure',
#  'EMR',
#  'Snowflake',
#  'AWS',
#  'MapReduce',
#  'BigQuery',
#  'Hubspot',
#  'OWNER',
#  'Geneva',
#  'Google',
#  'Ideas',
#  'Javascript',
#  'SQL',
#  'S3',
#  'Redshift',
#  'Hadoop',
#  'Flink',
#  'Kafka',
#  'SparkSQL',
#  'Hive',
#  'Spark',
#  'Python',
#  'Airflow',
#  'AWS',
#  'Athena',
#  'Java',
#  'Docker',
#  'Tensorflow',
#  'GCP',
#  'Azure',
#  'Python',
#  'Snowflake',
#  'Airflow',
#  'AWS',
#  'dbt',
#  'Javascript',
#  'SQL',
#  'PHP',
#  'NoSQL',
#  'Manager',
#  'SIP',
#  'Python',
#  'TLS',
#  'Ruby',
#  'GCP',
#  'Azure',
#  'Luigi',
#  'Python',
#  'Snowflake',
#  'AWS',
#  'Airflow',
#  'Kubernetes',
#  'BigQuery',
#  'Redshift',
#  'Ruby',
#  'Python',
#  'Fire',
#  'AWS',
#  'Perl',
#  'SQL',
#  'Datadog',
#  'Jenkins',
#  'Go lang',
#  'Beam',
#  'Google Cloud Platform',
#  'Flink',
#  'Dataflow',
#  'Python',
#  'Airflow',
#  'Kubernetes',
#  'Java',
#  'K8S',
#  'Docker',
#  'BigQuery',
#  'SQL',
#  'Apollo',
#  'Neo4J',
#  'GraphQL',
#  'Codecov',
#  'Node',
#  'Typescript',
#  'react',
#  'CircleCI',
#  'AWS',
#  'Postgres',
#  'Github',
#  'RabbitMQ',
#  'React',
#  'HTTP',
#  'Hadoop',
#  'NoSQL',
#  'Spark',
#  'Python',
#  'Java',
#  'BigQuery',
#  'SQL',
#  'Airbyte',
#  'DataBuildTool',
#  'StitchData',
#  'Metabase',
#  'Fivetran',
#  'Snowflake',
#  'Airflow',
#  'Python',
#  'BigQuery',
#  'SQL',
#  'S3',
#  'Hadoop',
#  'Scala',
#  'Flink',
#  'Glue',
#  'EMR',
#  'SQL',
#  'Spark',
#  'Python',
#  'AWS',
#  'Athena',
#  'Java',
#  'MapReduce',
#  'Kinesis',
#  'Fire',
#  'AWS',
#  'MySQL',
#  'PostgreSQL',
#  'ChartIO',
#  'Looker',
#  'Amazon Redshift',
#  'BigQuery',
#  'SQL',
#  'PowerPoint',
#  'TypeScript',
#  'Ostrava',
#  'SageMaker',
#  'Python',
#  'Kubernetes',
#  'AWS',
#  'Java',
#  'JavaScript',
#  'React',
#  'Ruby',
#  'Python',
#  'Fire',
#  'AWS',
#  'Java',
#  'SQL',
#  'Kimball',
#  'airflow',
#  'Microstrategy',
#  'Snowflake',
#  'dbt',
#  'Pagerduty',
#  'data vault',
#  'python',
#  'BigQuery',
#  'SQL',
#  'Luigi',
#  'airflow',
#  'Kafka',
#  'python',
#  'SQL',
#  'Groovy',
#  'Jenkins',
#  'TypeScript',
#  'Azure',
#  'Kafka',
#  'Kubernetes',
#  'AWS',
#  'Docker',
#  'React',
#  'Javascript',
#  'BPI',
#  'Python',
#  'Manager',
#  'React',
#  'Vue.\n ',
#  'GCP',
#  'Hadoop',
#  'Scala',
#  'Azure',
#  'Kafka',
#  'Spark',
#  'Python',
#  'LittleBigCode',
#  'AWS',
#  'SQL',
#  'AccorHotels',
#  'Azure',
#  'Python',
#  'AWS',
#  'Postgres',
#  'Instagram',
#  'BigQuery',
#  'SQL',
#  'Groovy',
#  'Jenkins',
#  'Ostrava',
#  'OOP',
#  'VSL',
#  'Pricemart',
#  'Java',
#  'Docker',
#  'WIT',
#  'Managed',
#  'SQL',
#  'Redshift',
#  'EMR',
#  'Superset',
#  'Spark',
#  'AWS',
#  'Athena',
#  'Airflow',
#  'Kubernetes',
#  'Tableau',
#  'Docker',
#  'HCI',
#  'Scala',
#  'Kafka',
#  'Go',
#  'Spark',
#  'AWS',
#  'Akka',
#  'Java',
#  'ClickHouse',
#  'Elasticsearch',
#  'NoSQL',
#  'Kafka',
#  'Go',
#  'Spark',
#  'Participating',
#  'Python',
#  'Snowflake',
#  'Linux',
#  'ElasticSearch',
#  'RabbitMQ',
#  'PHP',
#  'MySQL',
#  'SPAR',
#  'Hadoop',
#  'PowerBI',
#  'Scala',
#  'Unix',
#  'MAPR',
#  'Talend',
#  'InnovaFeed',
#  'Snowflake',
#  'Python',
#  'Tableau',
#  'Java',
#  'SQL',
#  'Tableau',
#  'SQL',
#  'ElasticSearch',
#  'GuideWire',
#  'SQL',
#  'S3',
#  'Redshift',
#  'Hadoop',
#  'Flink',
#  'Kafka',
#  'SparkSQL',
#  'Hive',
#  'Spark',
#  'Python',
#  'Swile',
#  'Airflow',
#  'AWS',
#  'Athena',
#  'Java',
#  'Docker',
#  'Tensorflow',
#  'Německu',
#  'B2B',
#  'prvních',
#  'Linux',
#  'Redux',
#  'Java',
#  'React',
#  'SQL',
#  'Grafana',
#  'MySQL',
#  'HTTP',
#  'Scala',
#  'Python',
#  'Kubernetes',
#  'Java',
#  'BigQuery',
#  'Sydney',
#  'Bases',
#  'NoSQL',
#  'Grafana',
#  'PostgreSQL',
#  'Kafka',
#  'Proficiency',
#  'Python',
#  'Airflow',
#  'Kubernetes',
#  'Prometheus',
#  'Java',
#  'ElasticSearch',
#  'BigQuery',
#  'Apache Beam',
#  'SQL',
#  'Fire',
#  'Tableau',
#  'AWS',
#  'S3',
#  'Redshift',
#  'Hadoop',
#  'Flink',
#  'Kafka',
#  'SparkSQL',
#  'Hive',
#  'Spark',
#  'Python',
#  'daily\u200e',
#  'Airflow',
#  'AWS',
#  'Athena',
#  'Java',
#  'Docker',
#  'Tensorflow',
#  'S3',
#  'MySQL',
#  'CircleCI',
#  'Metabase',
#  'Snowflake',
#  'Stitch',
#  'Airflow',
#  'Tableau',
#  'dbt',
#  'Python',
#  'SQL',
#  'Schedule',
#  'Bash',
#  'B2B',
#  'Google Cloud Platform',
#  'NoSQL',
#  'Beam',
#  'Kafka',
#  'Compute',
#  'Spark',
#  'Apache',
#  'Dataflow',
#  'Python',
#  'Airflow',
#  'Kubernetes',
#  'Java',
#  'Docker',
#  'BigQuery',
#  'SQL',
#  'MeilleurTaux.com',
#  'Python',
#  'Github',
#  'RabbitMQ',
#  'PostgreSQL',
#  'Fire',
#  'AWS',
#  'Python',
#  'Linux',
#  'SQL',
#  'Unix',
#  'MySQL',
#  'ScyllaDB',
#  'Kafka',
#  'Go',
#  'Python',
#  'ElasticSearch',
#  'Docker',
#  'Gitlab',
#  'Tensorflow',
#  'MySQL',
#  'Java',
#  'Kafka',
#  'Go',
#  'Talend',
#  'Metabase',
#  'Python',
#  'Airflow',
#  'Tableau',
#  'Elaia',
#  'Elasticsearch',
#  'Bpifrance',
#  'Kibana',
#  'Kimball',
#  'airflow',
#  'Microstrategy',
#  'Snowflake',
#  'dbt',
#  'Pagerduty',
#  'data vault',
#  'python',
#  'BigQuery',
#  'SQL',
#  'Redshift',
#  'Gamology',
#  'PowerBI',
#  'Pandas',
#  'Python',
#  'ElasticSearch',
#  'AWS',
#  'Instagram',
#  'python',
#  'Aurora',
#  'SQL',
#  'R',
#  'Python',
#  'Fire',
#  'AWS',
#  'SQL',
#  'Datadog',
#  'Hadoop',
#  'Luigi',
#  'Scala',
#  'Dublin',
#  'Kafka',
#  'Go',
#  'Spark',
#  'Python',
#  'Kubernetes',
#  'AWS',
#  'Java',
#  'Azure',
#  'AWS',
#  'SQL',
#  'Fire',
#  'AWS',
#  'Redshift',
#  'EMR',
#  'Superset',
#  'Spark',
#  'Swile',
#  'AWS',
#  'Athena',
#  'Airflow',
#  'Kubernetes',
#  'Tableau',
#  'Docker',
#  'S3',
#  'Jenkins',
#  'Kafka',
#  'Spark',
#  'Python',
#  'FileSystem',
#  'Java',
#  'Docker',
#  'PostgreSQL',
#  'SQL',
#  'Německu',
#  'prvních',
#  'Linux',
#  'Redux',
#  'Java',
#  'React',
#  'Fire',
#  'AWS',
#  'C#',
#  'NoSQL',
#  'SQL',
#  'S3',
#  'Redshift',
#  'Hadoop',
#  'Flink',
#  'Kafka',
#  'SparkSQL',
#  'Hive',
#  'Spark',
#  'Python',
#  'Airflow',
#  'AWS',
#  'Athena',
#  'Java',
#  'Docker',
#  'Tensorflow',
#  'PowerBI',
#  'Salesforce',
#  'Spark',
#  'Python',
#  'AngularJS',
#  'Kubernetes',
#  'Tableau',
#  'Java',
#  'Javascript',
#  'SQL',
#  'S3',
#  'Jenkins',
#  'EMR',
#  'Spark',
#  'Snowflake',
#  'Python',
#  'AWS',
#  'Airflow',
#  'Kubernetes',
#  'Docker',
#  'Elasticsearch',
#  'python',
#  'BigQuery',
#  'SQL',
#  'Fire',
#  'AWS',
#  'Scala',
#  'Proficiency',
#  'Azure',
#  'EMR',
#  'Python',
#  'Fire',
#  'AWS',
#  'SQL',
#  'HTTP',
#  'Hadoop',
#  'NoSQL',
#  'Spark',
#  'Python',
#  'Java',
#  'BigQuery',
#  'SQL',
#  'Dutch',
#  'German',
#  'Alven',
#  'Sweden',
#  'SQL',
#  'Pipedrive',
#  'Kubernetes',
#  'Looker',
#  'Fivetran',
#  'Python',
#  'Airflow',
#  'Postgres',
#  'BigQuery',
#  'SQL',
#  'Airbyte',
#  'Clémence',
#  'Metabase',
#  'Snowflake',
#  ...]

# %%
text = " ".join(tech for tech in all_technos)
text = text.lower()

# %%
word_cloud = WordCloud(background_color = 'black', max_words=80).generate(text)

tokens = word_tokenize(text)
counts = Counter(tokens)
counts.most_common()
# Out:
# [('python', 326),
#  ('sql', 259),
#  ('aws', 180),
#  ('spark', 121),
#  ('airflow', 117),
#  ('java', 112),
#  ('kafka', 95),
#  ('bigquery', 81),
#  ('kubernetes', 79),
#  ('docker', 70),
#  ('scala', 68),
#  ('redshift', 66),
#  ('azure', 61),
#  ('snowflake', 59),
#  ('google', 53),
#  ('elasticsearch', 51),
#  ('hadoop', 51),
#  ('dbt', 47),
#  ('tensorflow', 45),
#  ('r', 43),
#  ('tableau', 43),
#  ('cloud', 41),
#  ('go', 40),
#  ('s3', 35),
#  ('looker', 35),
#  ('flink', 35),
#  ('nosql', 34),
#  ('apache', 30),
#  ('postgresql', 28),
#  ('beam', 27),
#  ('mysql', 27),
#  ('grafana', 24),
#  ('javascript', 24),
#  ('linux', 24),
#  ('fire', 24),
#  ('hive', 23),
#  ('platform', 22),
#  ('mongodb', 22),
#  ('prometheus', 22),
#  ('swile', 22),
#  ('react', 21),
#  ('athena', 21),
#  ('pandas', 19),
#  ('microsoft', 18),
#  ('http', 17),
#  ('hdfs', 15),
#  ('fivetran', 14),
#  ('ruby', 14),
#  ('redis', 14),
#  ('emr', 14),
#  ('luigi', 13),
#  ('unix', 13),
#  ('rabbitmq', 13),
#  ('gcp', 13),
#  ('jenkins', 13),
#  ('php', 12),
#  ('powerbi', 12),
#  ('metabase', 12),
#  ('sparksql', 12),
#  ('typescript', 12),
#  ('dataflow', 11),
#  ('talend', 11),
#  ('dublin', 11),
#  ('salesforce', 11),
#  ('kibana', 10),
#  ('economics', 10),
#  ('scikit', 10),
#  ('c', 10),
#  ('https', 10),
#  (':', 10),
#  ('clickhouse', 9),
#  ('german', 9),
#  ('datadog', 9),
#  ('postgres', 9),
#  ('data', 9),
#  ('shift', 9),
#  ('dynamodb', 8),
#  ('proficiency', 8),
#  ('kinesis', 8),
#  ('circleci', 8),
#  ('github', 8),
#  ('akka', 8),
#  ('guidewire', 8),
#  ('kubeflow', 7),
#  ('sap', 7),
#  ('glue', 7),
#  ('kimball', 7),
#  ('microstrategy', 7),
#  ('pagerduty', 7),
#  ('vault', 7),
#  ('bigtable', 7),
#  ('drones', 7),
#  ('industrie', 7),
#  ('its', 7),
#  ('bash', 6),
#  ('chef', 6),
#  ('#', 6),
#  ('mapreduce', 6),
#  ('manager', 6),
#  ('instagram', 6),
#  ('no', 6),
#  ('css', 6),
#  ('you', 6),
#  ('payfit', 6),
#  ('argentina', 6),
#  ('sagemaker', 5),
#  ('golang', 5),
#  ('learn', 5),
#  ('bpi', 5),
#  ('b2b', 5),
#  ('redux', 5),
#  ('scaleway', 5),
#  ('peru', 5),
#  ('etl', 4),
#  ('pub/sub', 4),
#  ('puppet', 4),
#  ('dutch', 4),
#  ('pocs', 4),
#  ('sweden', 4),
#  ('perl', 4),
#  ('k8s', 4),
#  ('ostrava', 4),
#  ('groovy', 4),
#  ('accorhotels', 4),
#  ('participating', 4),
#  ('bpifrance', 4),
#  ('jira', 4),
#  ('would', 4),
#  ('i/o', 4),
#  ('tdd', 4),
#  ('macos', 4),
#  ('dock', 4),
#  ('tpu', 4),
#  ('lille', 4),
#  ('pytorch', 4),
#  ('c++', 4),
#  ('nginx', 4),
#  ('flyte', 3),
#  ('stackdriver', 3),
#  ('c/c++', 3),
#  ('pig', 3),
#  ('informatics', 3),
#  ('presales', 3),
#  ('pql', 3),
#  ('torch', 3),
#  ('free', 3),
#  ('net', 3),
#  ('geneva', 3),
#  ('ideas', 3),
#  ('graphql', 3),
#  ('airbyte', 3),
#  ('superset', 3),
#  ('německu', 3),
#  ('prvních', 3),
#  ('stitch', 3),
#  ('scylladb', 3),
#  ('gamology', 3),
#  ('aurora', 3),
#  ('angularjs', 3),
#  ('alven', 3),
#  ('heidelbergcement', 3),
#  ('sms', 3),
#  ('dvc', 3),
#  ('flask', 3),
#  ('switzerland', 3),
#  ('//owkin.welcomekit.co', 3),
#  ('quelques', 3),
#  ('fidelity', 3),
#  ('vienne', 3),
#  ('citizen', 3),
#  ('telecom', 3),
#  ('varnish', 3),
#  ('gitguardian', 3),
#  ('rennes', 3),
#  ('/', 3),
#  ('tools', 3),
#  ('gke', 2),
#  ('ceph', 2),
#  ('nifi', 2),
#  ('spectrum', 2),
#  ('astronomer', 2),
#  ('dax', 2),
#  ('vizql', 2),
#  ('sso', 2),
#  ('h20', 2),
#  ('rnn', 2),
#  ('oop', 2),
#  ('hubspot', 2),
#  ('owner', 2),
#  ('lang', 2),
#  ('node', 2),
#  ('databuildtool', 2),
#  ('stitchdata', 2),
#  ('powerpoint', 2),
#  ('littlebigcode', 2),
#  ('daily\u200e', 2),
#  ('schedule', 2),
#  ('compute', 2),
#  ('gitlab', 2),
#  ('elaia', 2),
#  ('quicksight', 2),
#  ('puma', 2),
#  ('burberry', 2),
#  ('swat', 2),
#  ('like', 2),
#  ('morocco', 2),
#  ('algeria', 2),
#  ('elastic', 2),
#  ('scrum', 2),
#  ('//www.implicity.com/ressource/implicity-and-withings-develop-a-solution-for-the-remote-monitoring-of-heart-failure-patients',
#   2),
#  ('agility', 2),
#  ('//www.implicity.com/about-us', 2),
#  ('platforms', 2),
#  ('gymlib', 2),
#  ('tva', 2),
#  ('trustpilot', 2),
#  ('usabilla', 2),
#  ('dask', 2),
#  ('posgresql', 2),
#  ('pipelines', 2),
#  ('ecs', 2),
#  ('10€/day', 2),
#  ('reactjs', 2),
#  ('.net', 2),
#  ('under', 2),
#  ('systems', 2),
#  ('proxyclick', 2),
#  ('graylog', 2),
#  ('logstash', 2),
#  ('influxdb', 2),
#  ('balderton', 2),
#  ('headline', 2),
#  ('mariadb', 2),
#  ('further', 2),
#  ('allbirds', 2),
#  ('programming', 2),
#  ('santé', 2),
#  ('replatform', 2),
#  ('web', 2),
#  ('geopost', 2),
#  ('camper', 2),
#  ('container', 2),
#  ('may', 2),
#  ('z', 2),
#  ('meltano', 2),
#  ('sqlpython', 2),
#  ('scheduler', 2),
#  ('implementations', 2),
#  ('anaconda', 2),
#  ('zero', 2),
#  ('transformation', 2),
#  ('backmarket', 2),
#  ('ssis', 2),
#  ('edit', 2),
#  ('mlflow', 1),
#  ('nodejs', 1),
#  ('cloudsql', 1),
#  ('spanner', 1),
#  ('vitess', 1),
#  ('salt', 1),
#  ('quicksilver', 1),
#  ('cockroachdb', 1),
#  ('opentsdb', 1),
#  ('mttr', 1),
#  ('woocommerce', 1),
#  ('longreads', 1),
#  ('terms', 1),
#  ('serviceportal', 1),
#  ('py', 1),
#  ('scikitlearn', 1),
#  ('payments', 1),
#  ('storm', 1),
#  ('protocols', 1),
#  ('est', 1),
#  ('gan', 1),
#  ('gdpr', 1),
#  ('event', 1),
#  ('eks', 1),
#  ('sip', 1),
#  ('tls', 1),
#  ('apollo', 1),
#  ('neo4j', 1),
#  ('codecov', 1),
#  ('chartio', 1),
#  ('amazon', 1),
#  ('vue', 1),
#  ('.', 1),
#  ('vsl', 1),
#  ('pricemart', 1),
#  ('wit', 1),
#  ('managed', 1),
#  ('hci', 1),
#  ('spar', 1),
#  ('mapr', 1),
#  ('innovafeed', 1),
#  ('sydney', 1),
#  ('bases', 1),
#  ('meilleurtaux.com', 1),
#  ('filesystem', 1),
#  ('pipedrive', 1),
#  ('clémence', 1),
#  ('//www.linkedin.com/in/arnaudcoutin', 1),
#  ('//www.linkedin.com/in/clémence-coghlan-3bab312b/', 1),
#  ('mandarin', 1),
#  ('electrical', 1),
#  ('rca', 1),
#  ('b2', 1),
#  ('oozie', 1),
#  ('f', 1),
#  ('forms', 1),
#  ('bms', 1),
#  ('c/c++/rust', 1),
#  ('wishing', 1),
#  ('daphni', 1),
#  ('app', 1),
#  ('flyer', 1),
#  ('storage', 1),
#  ('playstation', 1),
#  ('as', 1),
#  ('a', 1),
#  ('xslt', 1),
#  ('t', 1),
#  ('￡10', 1),
#  ('edenred', 1),
#  ('p3', 1),
#  ('streams', 1),
#  ('m2', 1),
#  ('ingolstadt', 1),
#  ('optional', 1),
#  ('externally', 1),
#  ('alma', 1),
#  ('remove', 1),
#  ('asian', 1),
#  ('adobe', 1),
#  ('clients', 1),
#  ('translators', 1),
#  ('pdi', 1),
#  ('qlik', 1),
#  ('creation', 1),
#  ('yarn', 1),
#  ('nfs', 1),
#  ('mifid', 1),
#  ('pamguard', 1),
#  ('fairo', 1),
#  ('assurance', 1),
#  ('service', 1),
#  ('bus', 1),
#  ('descartes', 1),
#  ('lamp', 1),
#  ('timescaledb', 1),
#  ('fargate', 1),
#  ('3-', 1),
#  ('sketch', 1),
#  ('pto', 1),
#  ('purchasing', 1),
#  ('mail', 1),
#  ('e2e', 1),
#  ('information', 1),
#  ('specialty', 1),
#  ('💁', 1),
#  ('arr', 1),
#  ('triple', 1),
#  ('sop', 1),
#  ('ngs', 1),
#  ('weblogic', 1),
#  ('openshift', 1),
#  ('ajax', 1),
#  ('websphere', 1),
#  ('aft', 1),
#  ('nadja', 1),
#  ('onboarding', 1),
#  ('ansible', 1),
#  ('codebuild', 1),
#  ('bing', 1),
#  ('shop', 1),
#  ('matthieu', 1),
#  ('//agicap.com/de/artikel/agicap-deutschland', 1),
#  ('institut', 1),
#  ('commercexm', 1),
#  (',', 1),
#  ('kima', 1),
#  ('observe', 1),
#  ('hls', 1),
#  ('basic', 1),
#  ('hermes', 1),
#  ('f5', 1),
#  ('bitcoin', 1),
#  ('villejuif', 1),
#  ('tailored', 1),
#  ('www.abtasty.com', 1),
#  ('smb', 1),
#  ('git', 1),
#  ('macgyver', 1),
#  ('atdd', 1),
#  ('entreprises', 1),
#  ('babel', 1),
#  ('v2i', 1),
#  ('crunch', 1),
#  ('scripting', 1),
#  ('allowances', 1),
#  ('openstack', 1),
#  ('backend', 1),
#  ('dropbox', 1),
#  ('ogury', 1),
#  ('oppscience', 1),
#  ('vmware', 1),
#  ('allows', 1),
#  ('our', 1),
#  ('ejb', 1),
#  ('datascience', 1),
#  ('bond', 1),
#  ('install', 1),
#  ('integration', 1),
#  ('ojdbc', 1),
#  ('sqlserver', 1),
#  ('webservices', 1),
#  ('aml', 1),
#  ('appliance', 1),
#  ('documentation', 1),
#  ('eager', 1),
#  ('manufacturers', 1),
#  ('simulation', 1),
#  ('provision', 1),
#  ('lectra', 1),
#  ('macbooks', 1),
#  ('ovh', 1),
#  ('workspace', 1),
#  ('delivery', 1),
#  ('q3', 1),
#  ('december', 1),
#  ('slovakia', 1)]

# %%
plt.figure(figsize=(10,10), dpi=300)
plt.axis('off')
plt.imshow(word_cloud)
plt.savefig('wordcloud.png');
