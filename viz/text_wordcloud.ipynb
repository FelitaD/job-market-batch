# %%
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from collections import Counter
import string
import re
import nltk
from nltk.stem import PorterStemmer, WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
nltk.download('stopwords')
# %matplotlib inline
# Out:
# [nltk_data] Downloading package stopwords to /Users/donor/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
jobs = pd.read_csv('/Users/donor/PycharmProjects/DE_job_market/nlp/english_jobs_ner.csv', index_col=[0])
jobs
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [12], in <module>
# ----> 1 jobs = pd.read_csv('./nlp/english_jobs_ner.csv', index_col=[0])
#       2 jobs
#
# File ~/PycharmProjects/Reviews/venv/lib/python3.9/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/PycharmProjects/Reviews/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:680, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     665 kwds_defaults = _refine_defaults_read(
#     666     dialect,
#     667     delimiter,
#    (...)
#     676     defaults={"delimiter": ","},
#     677 )
#     678 kwds.update(kwds_defaults)
# --> 680 return _read(filepath_or_buffer, kwds)
#
# File ~/PycharmProjects/Reviews/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~/PycharmProjects/Reviews/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:933, in TextFileReader.__init__(self, f, engine, **kwds)
#     930     self.options["has_index_names"] = kwds["has_index_names"]
#     932 self.handles: IOHandles | None = None
# --> 933 self._engine = self._make_engine(f, self.engine)
#
# File ~/PycharmProjects/Reviews/venv/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1217, in TextFileReader._make_engine(self, f, engine)
#    1213     mode = "rb"
#    1214 # error: No overload variant of "get_handle" matches argument types
#    1215 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1216 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1217 self.handles = get_handle(  # type: ignore[call-overload]
#    1218     f,
#    1219     mode,
#    1220     encoding=self.options.get("encoding", None),
#    1221     compression=self.options.get("compression", None),
#    1222     memory_map=self.options.get("memory_map", False),
#    1223     is_text=is_text,
#    1224     errors=self.options.get("encoding_errors", "strict"),
#    1225     storage_options=self.options.get("storage_options", None),
#    1226 )
#    1227 assert self.handles is not None
#    1228 f = self.handles.handle
#
# File ~/PycharmProjects/Reviews/venv/lib/python3.9/site-packages/pandas/io/common.py:789, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     784 elif isinstance(handle, str):
#     785     # Check whether the filename is to be opened in binary mode.
#     786     # Binary mode does not support 'encoding' and 'newline'.
#     787     if ioargs.encoding and "b" not in ioargs.mode:
#     788         # Encoding
# --> 789         handle = open(
#     790             handle,
#     791             ioargs.mode,
#     792             encoding=ioargs.encoding,
#     793             errors=errors,
#     794             newline="",
#     795         )
#     796     else:
#     797         # Binary mode
#     798         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: './nlp/english_jobs_ner.csv'

# %%
custom_stopwords = ['cookie', 'cooky', 'bloqué', 'contenu', 'voir', 'content', 'blocked', 'accepte', 'accepter', 'youtube', 'required', 'show', 'etc', 'sexual', 'orientation', 'plus', 'cooky accept', 'gender', 'identity']
stop_words = stopwords.words('english') + stopwords.words('french') + custom_stopwords
stemmatizer = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
def preprocess_text_wordcloud(text):
    # Remove spaces at the beginning of entire text
    text = re.sub('^[\\]n[\s]*', '', text)
    # Remove punctuation
    text = text.translate(str.maketrans("","",string.punctuation))
    text = re.sub('[^\w\s]', '', text)
    # Remove digits
    text = re.sub('[\d]', '', text)
    # Lowering
    text = text.lower()
    # Tokenizing
    tokens = word_tokenize(text)
    # Remove whitespaces
    tokens = [token.strip() for token in tokens]
    # Remove stop words
    tokens = [token for token in tokens if token not in stop_words]
    # Stemmatizing / lemmatizing
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    # Joining
    processed_text = ' '.join(tokens)
    return processed_text

# %%
jobs['processed_text'] = jobs['text'].apply(lambda x: preprocess_text_wordcloud(x))

# %%
text = " ".join(text for text in jobs.processed_text)
word_cloud = WordCloud(background_color = 'black', max_words=80).generate(text)

tokens = word_tokenize(text)
counts = Counter(tokens)
counts.most_common()
# Out:
# [('data', 4750),
#  ('team', 2889),
#  ('experience', 2084),
#  ('work', 1679),
#  ('business', 1140),
#  ('product', 1118),
#  ('company', 986),
#  ('new', 919),
#  ('u', 880),
#  ('technology', 876),
#  ('customer', 835),
#  ('engineering', 803),
#  ('skill', 796),
#  ('platform', 780),
#  ('engineer', 765),
#  ('working', 762),
#  ('solution', 736),
#  ('help', 697),
#  ('opportunity', 680),
#  ('environment', 659),
#  ('technical', 650),
#  ('cooky', 650),
#  ('build', 647),
#  ('process', 634),
#  ('learning', 630),
#  ('project', 598),
#  ('tool', 583),
#  ('year', 572),
#  ('knowledge', 562),
#  ('system', 556),
#  ('development', 551),
#  ('people', 544),
#  ('service', 543),
#  ('one', 540),
#  ('client', 539),
#  ('strong', 538),
#  ('design', 535),
#  ('world', 529),
#  ('need', 524),
#  ('across', 521),
#  ('make', 516),
#  ('join', 509),
#  ('office', 498),
#  ('user', 496),
#  ('like', 489),
#  ('looking', 484),
#  ('software', 482),
#  ('use', 472),
#  ('best', 459),
#  ('support', 429),
#  ('building', 425),
#  ('science', 418),
#  ('model', 417),
#  ('mission', 413),
#  ('role', 413),
#  ('machine', 411),
#  ('within', 408),
#  ('global', 406),
#  ('paris', 397),
#  ('good', 395),
#  ('employee', 393),
#  ('part', 391),
#  ('growth', 391),
#  ('management', 388),
#  ('value', 388),
#  ('python', 386),
#  ('develop', 383),
#  ('ability', 375),
#  ('using', 372),
#  ('application', 372),
#  ('want', 364),
#  ('pipeline', 363),
#  ('infrastructure', 361),
#  ('analytics', 357),
#  ('sql', 356),
#  ('time', 356),
#  ('tech', 351),
#  ('offer', 348),
#  ('quality', 347),
#  ('cloud', 347),
#  ('day', 345),
#  ('problem', 342),
#  ('accept', 339),
#  ('culture', 329),
#  ('english', 326),
#  ('youll', 325),
#  ('improve', 324),
#  ('million', 322),
#  ('including', 320),
#  ('impact', 320),
#  ('language', 319),
#  ('veepee', 319),
#  ('every', 313),
#  ('way', 311),
#  ('marketing', 304),
#  ('learn', 303),
#  ('performance', 301),
#  ('analysis', 297),
#  ('aws', 288),
#  ('understand', 287),
#  ('europe', 285),
#  ('well', 285),
#  ('challenge', 283),
#  ('test', 280),
#  ('communication', 276),
#  ('also', 275),
#  ('manager', 275),
#  ('take', 272),
#  ('get', 270),
#  ('around', 268),
#  ('code', 268),
#  ('create', 267),
#  ('interview', 265),
#  ('partner', 260),
#  ('implement', 259),
#  ('job', 259),
#  ('scientist', 257),
#  ('provide', 256),
#  ('database', 255),
#  ('internal', 254),
#  ('scale', 251),
#  ('member', 251),
#  ('production', 249),
#  ('status', 248),
#  ('insight', 247),
#  ('requirement', 247),
#  ('equal', 247),
#  ('information', 243),
#  ('high', 243),
#  ('digital', 243),
#  ('set', 242),
#  ('practice', 241),
#  ('decision', 239),
#  ('amazon', 239),
#  ('maintain', 238),
#  ('based', 236),
#  ('different', 235),
#  ('big', 235),
#  ('know', 234),
#  ('international', 234),
#  ('complex', 232),
#  ('right', 230),
#  ('ensure', 227),
#  ('find', 225),
#  ('sale', 224),
#  ('success', 221),
#  ('great', 221),
#  ('understanding', 219),
#  ('key', 217),
#  ('strategy', 216),
#  ('passionate', 215),
#  ('architecture', 214),
#  ('together', 213),
#  ('stack', 213),
#  ('better', 211),
#  ('leading', 209),
#  ('country', 209),
#  ('diverse', 208),
#  ('source', 208),
#  ('community', 207),
#  ('industry', 207),
#  ('growing', 207),
#  ('european', 206),
#  ('remote', 206),
#  ('delivery', 204),
#  ('startup', 203),
#  ('position', 203),
#  ('responsibility', 201),
#  ('feature', 200),
#  ('level', 200),
#  ('able', 198),
#  ('apply', 195),
#  ('testing', 192),
#  ('processing', 191),
#  ('algorithm', 191),
#  ('dataiku', 188),
#  ('future', 187),
#  ('candidate', 187),
#  ('love', 185),
#  ('group', 185),
#  ('many', 183),
#  ('market', 181),
#  ('field', 181),
#  ('career', 181),
#  ('deliver', 181),
#  ('event', 181),
#  ('computer', 180),
#  ('payment', 180),
#  ('possible', 178),
#  ('programming', 178),
#  ('individual', 178),
#  ('large', 177),
#  ('innovative', 177),
#  ('benefit', 176),
#  ('disability', 176),
#  ('drive', 176),
#  ('brand', 176),
#  ('today', 175),
#  ('expertise', 174),
#  ('dont', 173),
#  ('always', 172),
#  ('everyone', 171),
#  ('stakeholder', 170),
#  ('highly', 170),
#  ('unique', 169),
#  ('first', 168),
#  ('employer', 168),
#  ('warehouse', 168),
#  ('airflow', 165),
#  ('closely', 165),
#  ('life', 164),
#  ('spark', 164),
#  ('excellent', 163),
#  ('making', 162),
#  ('grow', 162),
#  ('online', 162),
#  ('professional', 161),
#  ('issue', 161),
#  ('operation', 160),
#  ('place', 160),
#  ('degree', 160),
#  ('week', 160),
#  ('background', 159),
#  ('meet', 158),
#  ('analyst', 158),
#  ('dynamic', 158),
#  ('organization', 157),
#  ('manage', 157),
#  ('least', 156),
#  ('distributed', 155),
#  ('come', 155),
#  ('used', 155),
#  ('open', 153),
#  ('integration', 153),
#  ('youre', 153),
#  ('next', 153),
#  ('home', 152),
#  ('believe', 152),
#  ('lead', 152),
#  ('share', 152),
#  ('security', 152),
#  ('insurance', 151),
#  ('identify', 151),
#  ('flexible', 150),
#  ('developer', 149),
#  ('location', 148),
#  ('vision', 148),
#  ('spotify', 148),
#  ('contribute', 148),
#  ('developing', 148),
#  ('deep', 147),
#  ('hour', 146),
#  ('billion', 146),
#  ('thing', 146),
#  ('deployment', 146),
#  ('religion', 145),
#  ('leader', 145),
#  ('various', 144),
#  ('result', 144),
#  ('intelligence', 144),
#  ('without', 143),
#  ('focus', 142),
#  ('race', 142),
#  ('responsible', 142),
#  ('diversity', 142),
#  ('core', 141),
#  ('personal', 141),
#  ('solve', 141),
#  ('plan', 141),
#  ('talent', 141),
#  ('idea', 140),
#  ('age', 140),
#  ('call', 140),
#  ('framework', 138),
#  ('real', 138),
#  ('kafka', 137),
#  ('expert', 137),
#  ('per', 136),
#  ('several', 136),
#  ('transformation', 136),
#  ('training', 136),
#  ('saas', 136),
#  ('goal', 135),
#  ('daily', 135),
#  ('written', 135),
#  ('france', 135),
#  ('analytical', 134),
#  ('french', 134),
#  ('network', 133),
#  ('fluent', 133),
#  ('external', 132),
#  ('related', 132),
#  ('policy', 131),
#  ('research', 129),
#  ('similar', 128),
#  ('reporting', 128),
#  ('variety', 128),
#  ('committed', 127),
#  ('eg', 126),
#  ('web', 126),
#  ('collaboration', 126),
#  ('power', 126),
#  ('automation', 126),
#  ('hiring', 125),
#  ('apache', 125),
#  ('order', 125),
#  ('datadog', 125),
#  ('program', 125),
#  ('leurs', 125),
#  ('bring', 124),
#  ('creative', 124),
#  ('andor', 124),
#  ('employment', 124),
#  ('designing', 124),
#  ('activity', 124),
#  ('even', 123),
#  ('multiple', 122),
#  ('care', 122),
#  ('improvement', 121),
#  ('creating', 120),
#  ('approach', 120),
#  ('globally', 120),
#  ('player', 120),
#  ('recruitment', 120),
#  ('go', 119),
#  ('inclusive', 118),
#  ('innovation', 118),
#  ('fast', 118),
#  ('full', 118),
#  ('would', 117),
#  ('origin', 117),
#  ('potential', 117),
#  ('action', 117),
#  ('kubernetes', 116),
#  ('access', 115),
#  ('talented', 115),
#  ('passion', 115),
#  ('enable', 114),
#  ('may', 114),
#  ('competitive', 114),
#  ('master', 114),
#  ('needed', 113),
#  ('google', 113),
#  ('advanced', 113),
#  ('following', 113),
#  ('ml', 112),
#  ('agile', 112),
#  ('scalable', 112),
#  ('proud', 112),
#  ('critical', 112),
#  ('monitoring', 112),
#  ('video', 112),
#  ('barcelona', 111),
#  ('collaborate', 110),
#  ('fully', 110),
#  ('backend', 109),
#  ('national', 109),
#  ('task', 109),
#  ('health', 108),
#  ('implementation', 107),
#  ('comfortable', 107),
#  ('communicate', 106),
#  ('relevant', 106),
#  ('experienced', 104),
#  ('vehicle', 104),
#  ('bigquery', 104),
#  ('keep', 104),
#  ('continuous', 104),
#  ('point', 104),
#  ('define', 104),
#  ('weve', 104),
#  ('venteprivee', 104),
#  ('paid', 103),
#  ('department', 103),
#  ('matter', 103),
#  ('datadriven', 103),
#  ('raised', 103),
#  ('thrive', 102),
#  ('java', 102),
#  ('others', 102),
#  ('currently', 102),
#  ('nice', 102),
#  ('stuart', 102),
#  ('reliability', 101),
#  ('deploy', 101),
#  ('ambitious', 101),
#  ('welcome', 100),
#  ('enjoy', 100),
#  ('standard', 100),
#  ('existing', 100),
#  ('helping', 99),
#  ('mobility', 99),
#  ('center', 99),
#  ('mobile', 99),
#  ('implementing', 99),
#  ('please', 99),
#  ('strategic', 99),
#  ('basis', 99),
#  ('automate', 98),
#  ('initiative', 98),
#  ('creativity', 98),
#  ('area', 98),
#  ('method', 98),
#  ('curious', 98),
#  ('report', 97),
#  ('founded', 97),
#  ('social', 97),
#  ('must', 97),
#  ('remotely', 97),
#  ('month', 97),
#  ('docker', 97),
#  ('contentsquare', 97),
#  ('main', 96),
#  ('autonomous', 95),
#  ('case', 95),
#  ('offering', 95),
#  ('asset', 95),
#  ('top', 95),
#  ('colleague', 95),
#  ('run', 95),
#  ('efficient', 94),
#  ('change', 94),
#  ('query', 94),
#  ('mindset', 94),
#  ('providing', 93),
#  ('ecosystem', 93),
#  ('see', 93),
#  ('london', 93),
#  ('free', 93),
#  ('metric', 92),
#  ('leadership', 92),
#  ('available', 92),
#  ('built', 92),
#  ('mean', 92),
#  ('local', 92),
#  ('shift', 92),
#  ('ambition', 92),
#  ('operate', 91),
#  ('option', 91),
#  ('participate', 91),
#  ('fit', 91),
#  ('profile', 91),
#  ('protected', 90),
#  ('ensuring', 90),
#  ('technique', 90),
#  ('review', 90),
#  ('think', 90),
#  ('city', 90),
#  ('give', 89),
#  ('focused', 89),
#  ('collaborative', 89),
#  ('bi', 89),
#  ('fraud', 89),
#  ('include', 89),
#  ('collaborateurs', 89),
#  ('driven', 88),
#  ('reliable', 88),
#  ('capability', 88),
#  ('visualization', 88),
#  ('acquisition', 88),
#  ('ecommerce', 88),
#  ('methodology', 87),
#  ('conference', 87),
#  ('gcp', 87),
#  ('realtime', 86),
#  ('scala', 86),
#  ('question', 86),
#  ('spirit', 86),
#  ('since', 85),
#  ('store', 85),
#  ('dashboard', 85),
#  ('color', 85),
#  ('dbt', 85),
#  ('york', 85),
#  ('modern', 84),
#  ('maintaining', 84),
#  ('equivalent', 84),
#  ('constantly', 84),
#  ('modeling', 84),
#  ('writing', 84),
#  ('equipment', 83),
#  ('everything', 83),
#  ('financial', 83),
#  ('ready', 83),
#  ('optimization', 83),
#  ('scalability', 83),
#  ('vptech', 83),
#  ('ideally', 82),
#  ('latest', 82),
#  ('optimize', 82),
#  ('api', 82),
#  ('workforce', 82),
#  ('present', 82),
#  ('statistic', 82),
#  ('familiarity', 82),
#  ('range', 82),
#  ('internet', 82),
#  ('functional', 81),
#  ('etl', 81),
#  ('live', 81),
#  ('designer', 81),
#  ('improving', 81),
#  ('two', 81),
#  ('feedback', 81),
#  ('operational', 81),
#  ('concept', 81),
#  ('measure', 81),
#  ('analyze', 81),
#  ('apis', 80),
#  ('interest', 80),
#  ('quickly', 80),
#  ('pay', 80),
#  ('investor', 79),
#  ('quantitative', 79),
#  ('globe', 79),
#  ('solving', 79),
#  ('excellence', 79),
#  ('datasets', 79),
#  ('relationship', 79),
#  ('stripe', 79),
#  ('rd', 79),
#  ('enabling', 78),
#  ('streaming', 78),
#  ('exciting', 78),
#  ('azure', 78),
#  ('detail', 78),
#  ('package', 78),
#  ('journey', 78),
#  ('applicant', 77),
#  ('interested', 77),
#  ('efficiency', 77),
#  ('commerce', 77),
#  ('site', 77),
#  ('workplace', 76),
#  ('sharing', 76),
#  ('finance', 76),
#  ('write', 76),
#  ('sustainable', 76),
#  ('everyday', 76),
#  ('collect', 75),
#  ('smart', 75),
#  ('dedicated', 75),
#  ('enterprise', 75),
#  ('already', 75),
#  ('cost', 75),
#  ('feel', 75),
#  ('redshift', 75),
#  ('driving', 74),
#  ('familiar', 74),
#  ('devops', 74),
#  ('autonomy', 74),
#  ('recommendation', 74),
#  ('checkoutcom', 74),
#  ('innovate', 74),
#  ('law', 74),
#  ('compensation', 74),
#  ('let', 74),
#  ('execution', 74),
#  ('tous', 74),
#  ('look', 73),
#  ('sex', 73),
#  ('domain', 73),
#  ('volume', 73),
#  ('joining', 73),
#  ('monitor', 73),
#  ('biggest', 73),
#  ('context', 72),
#  ('clear', 72),
#  ('launched', 72),
#  ('sure', 72),
#  ('aim', 72),
#  ('celonis', 72),
#  ('friendly', 72),
#  ('made', 72),
#  ('singapore', 72),
#  ('brussels', 72),
#  ('start', 71),
#  ('meeting', 71),
#  ('located', 71),
#  ('trust', 71),
#  ('back', 71),
#  ('whole', 71),
#  ('lake', 71),
#  ('chance', 70),
#  ('consumer', 70),
#  ('music', 70),
#  ('empower', 70),
#  ('handson', 70),
#  ('snowflake', 70),
#  ('class', 70),
#  ('effective', 70),
#  ('regular', 70),
#  ('directly', 69),
#  ('tooling', 69),
#  ('unlock', 69),
#  ('state', 69),
#  ('taking', 69),
#  ('website', 69),
#  ('logistics', 69),
#  ('delivering', 68),
#  ('coding', 68),
#  ('structure', 68),
#  ('hundred', 68),
#  ('preferably', 68),
#  ('privacy', 68),
#  ('looker', 68),
#  ('documentation', 68),
#  ('regard', 68),
#  ('eager', 68),
#  ('thats', 67),
#  ('difference', 67),
#  ('youve', 67),
#  ('either', 67),
#  ('choice', 67),
#  ('hire', 67),
#  ('wide', 67),
#  ('check', 67),
#  ('workflow', 67),
#  ('achieve', 67),
#  ('claim', 67),
#  ('hr', 67),
#  ('thousand', 66),
#  ('amsterdam', 66),
#  ('veteran', 66),
#  ('perspective', 66),
#  ('art', 66),
#  ('includes', 66),
#  ('strive', 66),
#  ('fun', 66),
#  ('leave', 66),
#  ('headquartered', 66),
#  ('frontend', 66),
#  ('ab', 66),
#  ('industrial', 66),
#  ('insurer', 66),
#  ('storage', 65),
#  ('elasticsearch', 65),
#  ('topic', 65),
#  ('apps', 65),
#  ('end', 65),
#  ('salary', 65),
#  ('motivated', 65),
#  ('public', 65),
#  ('allows', 65),
#  ('developed', 65),
#  ('transportation', 64),
#  ('creator', 64),
#  ('worldwide', 64),
#  ('forward', 64),
#  ('automated', 64),
#  ('bonus', 64),
#  ('answer', 64),
#  ('type', 64),
#  ('detection', 64),
#  ('willing', 64),
#  ('pricing', 64),
#  ('base', 63),
#  ('put', 63),
#  ('qualified', 63),
#  ('statistical', 63),
#  ('inclusion', 63),
#  ('fastgrowing', 63),
#  ('achieved', 63),
#  ('lyon', 63),
#  ('marital', 62),
#  ('ask', 62),
#  ('hard', 62),
#  ('much', 62),
#  ('important', 62),
#  ('cloudflare', 62),
#  ('via', 62),
#  ('shape', 62),
#  ('commercial', 62),
#  ('successful', 62),
#  ('nationality', 62),
#  ('become', 62),
#  ('adventure', 62),
#  ('proven', 61),
#  ('perform', 61),
#  ('organisation', 61),
#  ('direct', 61),
#  ('person', 61),
#  ('provides', 61),
#  ('creation', 61),
#  ('monthly', 61),
#  ('term', 61),
#  ('contract', 61),
#  ('flow', 61),
#  ('produits', 61),
#  ('nantes', 61),
#  ('moment', 60),
#  ('central', 60),
#  ('significant', 60),
#  ('applying', 60),
#  ('tableau', 60),
#  ('proactive', 60),
#  ('close', 60),
#  ('solid', 60),
#  ('heart', 59),
#  ('energy', 59),
#  ('continuously', 59),
#  ('control', 59),
#  ('transform', 59),
#  ('git', 59),
#  ('box', 59),
#  ('qualification', 59),
#  ('onboarding', 59),
#  ('risk', 59),
#  ('friend', 59),
#  ('previous', 59),
#  ('monde', 59),
#  ('launch', 58),
#  ('crossfunctional', 58),
#  ('document', 58),
#  ('expression', 58),
#  ('space', 58),
#  ('cicd', 58),
#  ('server', 58),
#  ('resource', 58),
#  ('condition', 58),
#  ('proficiency', 58),
#  ('transport', 58),
#  ('aspect', 58),
#  ('owkin', 58),
#  ('track', 57),
#  ('complete', 57),
#  ('whats', 57),
#  ('current', 57),
#  ('objective', 57),
#  ('series', 57),
#  ('fastpaced', 57),
#  ('physical', 57),
#  ('long', 57),
#  ('pattern', 57),
#  ('account', 57),
#  ('madrid', 57),
#  ('simple', 57),
#  ('dune', 57),
#  ('number', 56),
#  ('version', 56),
#  ('crm', 56),
#  ('commitment', 56),
#  ('line', 56),
#  ('balance', 56),
#  ('verbal', 56),
#  ('step', 56),
#  ('thanks', 56),
#  ('na', 56),
#  ('v', 56),
#  ('usage', 55),
#  ('card', 55),
#  ('entrepreneur', 55),
#  ('request', 55),
#  ('managing', 55),
#  ('try', 55),
#  ('purpose', 55),
#  ('minimum', 55),
#  ('voucher', 55),
#  ('size', 55),
#  ('expect', 54),
#  ('driver', 54),
#  ('senior', 54),
#  ('contact', 54),
#  ('zone', 54),
#  ('human', 54),
#  ('largescale', 54),
#  ('celebrate', 54),
#  ('sense', 54),
#  ('accelerate', 54),
#  ('ever', 54),
#  ('executive', 54),
#  ('revenue', 54),
#  ('worklife', 54),
#  ('parmi', 54),
#  ('medical', 53),
#  ('finding', 53),
#  ('ownership', 53),
#  ('increase', 53),
#  ('happy', 53),
#  ('protection', 53),
#  ('serve', 53),
#  ('study', 53),
#  ('backed', 53),
#  ('funding', 53),
#  ('detect', 53),
#  ('provider', 53),
#  ('phone', 53),
#  ('nouvelles', 53),
#  ('dailymotion', 53),
#  ('explore', 52),
#  ('record', 52),
#  ('mathematics', 52),
#  ('belief', 52),
#  ('availability', 52),
#  ('reach', 52),
#  ('zapier', 52),
#  ('read', 52),
#  ('demonstrate', 52),
#  ('merchant', 52),
#  ('warsaw', 52),
#  ('interact', 52),
#  ('game', 52),
#  ('privalia', 52),
#  ('venteexclusive', 52),
#  ('zlotewyprzedaze', 52),
#  ('eboutic', 52),
#  ('maintenance', 51),
#  ('voice', 51),
#  ('proficient', 51),
#  ('excited', 51),
#  ('date', 51),
#  ('partnership', 51),
#  ('leverage', 51),
#  ('marketplace', 51),
#  ('example', 51),
#  ('flexibility', 51),
#  ('tier', 51),
#  ('fire', 51),
#  ('meetups', 51),
#  ('scaling', 50),
#  ('rest', 50),
#  ('hadoop', 50),
#  ('audience', 50),
#  ('mental', 50),
#  ('lot', 50),
#  ('curiosity', 50),
#  ('trend', 50),
#  ('k', 50),
#  ('worked', 50),
#  ('exceptional', 50),
#  ('permet', 50),
#  ('head', 50),
#  ('presentation', 49),
#  ('opensource', 49),
#  ('continue', 49),
#  ('face', 49),
#  ('interface', 49),
#  ('guide', 49),
#  ('course', 49),
#  ('changing', 49),
#  ('linux', 49),
#  ('towards', 49),
#  ('additional', 49),
#  ('thinking', 49),
#  ('lunch', 49),
#  ('car', 48),
#  ('collection', 48),
#  ('optimizing', 48),
#  ('history', 48),
#  ('throughout', 48),
#  ('rapidly', 48),
#  ('san', 48),
#  ('francisco', 48),
#  ('contributing', 48),
#  ('equity', 48),
#  ('private', 48),
#  ('play', 48),
#  ('safety', 48),
#  ('organize', 48),
#  ('collective', 48),
#  ('kindle', 48),
#  ('payfit', 48),
#  ('scripting', 47),
#  ('behavior', 47),
#  ('annual', 47),
#  ('among', 47),
#  ('family', 47),
#  ('format', 47),
#  ('adyen', 47),
#  ('effort', 47),
#  ('travel', 47),
#  ('mind', 47),
#  ('tracking', 47),
#  ('hand', 47),
#  ('environmental', 47),
#  ('outsight', 47),
#  ('capital', 46),
#  ('allow', 46),
#  ('component', 46),
#  ('accommodation', 46),
#  ('automating', 46),
#  ('modelling', 46),
#  ('deploying', 46),
#  ('electrical', 46),
#  ('restaurant', 46),
#  ('dna', 46),
#  ('generation', 45),
#  ('charge', 45),
#  ('move', 45),
#  ('tensorflow', 45),
#  ('act', 45),
#  ('mode', 45),
#  ('experiment', 45),
#  ('powerful', 45),
#  ('regulation', 45),
#  ('javascript', 45),
#  ('saving', 45),
#  ('compliance', 45),
#  ('microservices', 45),
#  ('rapidement', 45),
#  ('entreprise', 45),
#  ('sector', 45),
#  ('app', 45),
#  ('evolve', 44),
#  ('anywhere', 44),
#  ('giving', 44),
#  ('meaningful', 44),
#  ('huge', 44),
#  ('connected', 44),
#  ('total', 44),
#  ('planning', 44),
#  ('challenging', 44),
#  ('engine', 44),
#  ('secure', 44),
#  ('receive', 44),
#  ('last', 44),
#  ('fluency', 44),
#  ('safe', 44),
#  ('party', 44),
#  ('bringing', 43),
#  ('easy', 43),
#  ('easily', 43),
#  ('side', 43),
#  ('consider', 43),
#  ('consistent', 43),
#  ('encourage', 43),
#  ('r', 43),
#  ('attention', 43),
#  ('excel', 43),
#  ('small', 43),
#  ('succeed', 43),
#  ('amazing', 43),
#  ('require', 43),
#  ('function', 43),
#  ('procedure', 43),
#  ('scope', 43),
#  ('roadmap', 43),
#  ('especially', 43),
#  ('cycle', 43),
#  ('robust', 43),
#  ('unit', 43),
#  ('fuel', 43),
#  ('allowance', 43),
#  ('retailer', 43),
#  ('pro', 43),
#  ('computing', 42),
#  ('highquality', 42),
#  ('popular', 42),
#  ('landscape', 42),
#  ('possibility', 42),
#  ('going', 42),
#  ('configuration', 42),
#  ('visit', 42),
#  ('statement', 42),
#  ('still', 42),
#  ('preferred', 42),
#  ('fulltime', 42),
#  ('tel', 42),
#  ('aviv', 42),
#  ('tokyo', 42),
#  ('jellysmack', 42),
#  ('predictive', 41),
#  ('sound', 41),
#  ('regardless', 41),
#  ('citizenship', 41),
#  ('shared', 41),
#  ('address', 41),
#  ('could', 41),
#  ('capacity', 41),
#  ('created', 41),
#  ('never', 41),
#  ('germany', 41),
#  ('participation', 41),
#  ('inhouse', 41),
#  ('terraform', 41),
#  ('positive', 41),
#  ('script', 41),
#  ('création', 41),
#  ('aujourdhui', 41),
#  ('nosql', 40),
#  ('handle', 40),
#  ('valuable', 40),
#  ('firm', 40),
#  ('governance', 40),
#  ('major', 40),
#  ('demonstrated', 40),
#  ('really', 40),
#  ('speed', 40),
#  ('budget', 40),
#  ('basic', 40),
#  ('story', 40),
#  ('qa', 40),
#  ('ingestion', 40),
#  ('obligatoire', 40),
#  ('artificial', 40),
#  ('supporting', 39),
#  ('someone', 39),
#  ('structured', 39),
#  ('prefer', 39),
#  ('amongst', 39),
#  ...]

# %%
plt.figure(figsize=(10,10), dpi=300)
plt.axis('off')
plt.imshow(word_cloud)
plt.savefig('wordcloud.png');
